# %%
with open("NBA_2004_Shots.csv", "r") as f:
    lines = f.readlines()
    data = []
    for line in lines[1:]:  # skip header line
        line = line.strip()       
        parts = line.split(",")   # split line into list
        if parts[15] == '3PT Field Goal' and parts[12] == 'Made Shot':  # check if it's a made 3-point shot
            data.append(parts)
# Out:
# [['2004',
#   '2003-04',
#   '1610612737',
#   'Atlanta Hawks',
#   '1536',
#   'Stephen Jackson',
#   'F',
#   'SF',
#   '04-14-2004',
#   '20301176',
#   'BOS',
#   'ATL',
#   'Made Shot',
#   'TRUE',
#   'Jump Shot',
#   '3PT Field Goal',
#   'Above the Break 3',
#   'Right Side Center',
#   'RC',
#   '24+ ft.',
#   '-9',
#   '28.95',
#   '25',
#   '4',
#   '2',
#   '3'],
#  ['2004',
#   '2003-04',
#   '1610612759',
#   'San Antonio Spurs',
#   '369',
#   'Charlie Ward',
#   'G',
#   'PG',
#   '04-14-2004',
#   '20301184',
#   'SAS',
#   'DEN',
#   'Made Shot',
#   'TRUE',
#   'Jump Shot',
#   '3PT Field Goal',
#   'Above the Break 3',
#   'Right Side Center',
#   'RC',
#   '24+ ft.',
#   '-13.3',
#   '26.15',
#   '24',
#   '4',
#   '2',
#   '28'],
#  ['2004',
#   '2003-04',
#   '1610612737',
#   'Atlanta Hawks',
#   '1536',
#   'Stephen Jackson',
#   'F',
#   'SF',
#   '04-14-2004',
#   '20301176',
#   'BOS',
#   'ATL',
#   'Made Shot',
#   'TRUE',
#   'Jump Shot',
# ...
